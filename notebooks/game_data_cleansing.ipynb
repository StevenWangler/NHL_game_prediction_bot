# %%
import pandas as pd
# Correct relative path from the notebooks directory to the csv file
print('sample set from raw data')
data = pd.read_csv('../data/raw/20222023_Detroit_Red_Wings_game_results.csv')
print(data.head())
# Out:
# sample set from raw data
#   abbrev away_abbrev  away_away_goals  away_blocks  away_faceoffWinningPctg  \
# 0    PIT         DET                6           15                     55.3
# 1    DET         CHI                4           10                     43.2
# 2    DET         WSH                2           11                     55.6
# 3    CHI         DET                3           10                     43.5
# 4    DET         PIT                3           16                     54.0
#
#    away_hits  away_id   away_name  away_pim away_powerPlayConversion  blocks  \
# 0         39       17   Red Wings        18                      2/2       6
# 1         25       16  Blackhawks         6                      1/4       9
# 2         31       15    Capitals         6                      0/2      13
# 3         15       17   Red Wings         8                      0/4       5
# 4         22        5    Penguins         4                      2/2      11
#
#    faceoffWinningPctg  hits  home_goals  id        name  pim  \
# 0                44.7    29           2   5    Penguins    4
# 1                56.8    36           2  17   Red Wings    8
# 2                44.4    25           0  17   Red Wings    6
# 3                56.5    21           0  16  Blackhawks   10
# 4                46.0    30           2  17   Red Wings    4
#
#   powerPlayConversion
# 0                 0/9
# 1                 0/3
# 2                 0/2
# 3                 0/3
# 4                 0/2

# %%
data.describe()
# Out:
#        away_away_goals  away_blocks  away_faceoffWinningPctg  away_hits  \
# count        90.000000    90.000000                90.000000  90.000000
# mean          3.055556    14.511111                48.484444  20.777778
# std           1.886446     5.313211                 7.628464   7.734031
# min           0.000000     6.000000                31.700000   6.000000
# 25%           1.250000    11.000000                43.250000  15.000000
# 50%           3.000000    13.000000                48.500000  20.000000
# 75%           5.000000    17.000000                53.050000  26.500000
# max           8.000000    31.000000                67.400000  39.000000
#
#          away_id   away_pim     blocks  faceoffWinningPctg       hits  \
# count  90.000000  90.000000  90.000000           90.000000  90.000000
# mean   16.855556   8.844444  13.666667           51.515556  22.033333
# std     9.858050   5.394361   5.344324            7.628464   7.079723
# min     1.000000   0.000000   4.000000           32.600000   8.000000
# 25%    13.250000   6.000000  10.000000           46.950000  17.000000
# 50%    17.000000   8.000000  13.000000           51.500000  22.000000
# 75%    17.000000  10.000000  17.000000           56.750000  27.000000
# max    55.000000  35.000000  28.000000           68.300000  38.000000
#
#        home_goals         id        pim
# count   90.000000  90.000000  90.000000
# mean     3.177778  17.100000   7.688889
# std      1.764683   9.873412   4.015824
# min      0.000000   1.000000   2.000000
# 25%      2.000000  14.250000   6.000000
# 50%      3.000000  17.000000   6.000000
# 75%      4.000000  17.000000  10.000000
# max      8.000000  55.000000  27.000000

# %%
import os
import pandas as pd
import numpy as np

# Define the directories
csv_directory = '../data/raw/'
processed_directory = '../data/processed/'

# Ensure the processed directory exists
os.makedirs(processed_directory, exist_ok=True)

# Process CSV files
for file_name in os.listdir(csv_directory):
    if file_name.endswith('.csv'):
        file_path = os.path.join(csv_directory, file_name)
        
        # Read the CSV file
        df = pd.read_csv(file_path)

        # Verify and convert percentage columns for faceoff winning percentage
        for col in ['away_faceoffWinningPctg', 'faceoffWinningPctg']:
            if col in df.columns and df[col].max() > 1:
                df[col] = df[col] / 100
        
        # Fill NaN values with zeros or an appropriate value/method
        df.fillna(0, inplace=True)

        # Dynamic numeric column handling
        numeric_columns = df.select_dtypes(include=[np.number]).columns.tolist()
        df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce').fillna(0)
game_results_Processed.csv
# Processed file saved to: ../data/processed/20212022_San_Jose_Sharks_game_results_Processed.csv
# Processed file saved to: ../data/processed/20192020_Vegas_Golden_Knights_game_results_Processed.csv
# Processed file saved to: ../data/processed/20192020_New_York_Islanders_game_results_Processed.csv
# Processed file saved to: ../data/processed/20222023_Edmonton_Oilers_game_results_Processed.csv
# Processed file saved to: ../data/processed/20222023_Nashville_Predators_game_results_Processed.csv
# Processed file saved to: ../data/processed/20192020_Detroit_Red_Wings_game_results_Processed.csv
# Processed file saved to: ../data/processed/20192020_St._Louis_Blues_game_results_Processed.csv
# Processed file saved to: ../data/processed/20192020_New_Jersey_Devils_game_results_Processed.csv
# Processed file saved to: ../data/processed/20202021_St._Louis_Blues_game_results_Processed.csv
# Processed file saved to: ../data/processed/20192020_Edmonton_Oilers_game_results_Processed.csv
# Processed file saved to: ../data/processed/20182019_Minnesota_Wild_game_results_Processed.csv
# Processed file saved to: ../data/processed/20202021_Nashville_Predators_game_results_Processed.csv
# Processed file saved to: ../data/processed/20212022_Colorado_Avalanche_game_results_Processed.csv
# Processed file saved to: ../data/processed/20192020_Anaheim_Ducks_game_results_Processed.csv
# Processed file saved to: ../data/processed/20182019_Colorado_Avalanche_game_results_Processed.csv
# Processed file saved to: ../data/processed/20202021_Edmonton_Oilers_game_results_Processed.csv
# Processed file saved to: ../data/processed/20212022_Philadelphia_Flyers_game_results_Processed.csv
# Processed file saved to: ../data/processed/20212022_Toronto_Maple_Leafs_game_results_Processed.csv
# Processed file saved to: ../data/processed/20212022_New_Jersey_Devils_game_results_Processed.csv
# Processed file saved to: ../data/processed/20212022_Calgary_Flames_game_results_Processed.csv
# Processed file saved to: ../data/processed/20202021_Detroit_Red_Wings_game_results_Processed.csv
# Processed file saved to: ../data/processed/20192020_Dallas_Stars_game_results_Processed.csv
# Processed file saved to: ../data/processed/20192020_Minnesota_Wild_game_results_Processed.csv
# Processed file saved to: ../data/processed/20222023_New_York_Islanders_game_results_Processed.csv

# %%
import pandas as pd
print('sample processed data')
data = pd.read_csv('../data/processed/20222023_Detroit_Red_Wings_game_results_Processed.csv')
print(data.head())
data.describe()
# Out:
# sample processed data
#   abbrev away_abbrev  away_away_goals  away_blocks  away_faceoffWinningPctg  \
# 0    PIT         DET                6           15                    0.553
# 1    DET         CHI                4           10                    0.432
# 2    DET         WSH                2           11                    0.556
# 3    CHI         DET                3           10                    0.435
# 4    DET         PIT                3           16                    0.540
#
#    away_hits  away_id   away_name  away_pim away_powerPlayConversion  blocks  \
# 0         39       17   Red Wings        18                      2/2       6
# 1         25       16  Blackhawks         6                      1/4       9
# 2         31       15    Capitals         6                      0/2      13
# 3         15       17   Red Wings         8                      0/4       5
# 4         22        5    Penguins         4                      2/2      11
#
#    faceoffWinningPctg  hits  home_goals  id        name  pim  \
# 0               0.447    29           2   5    Penguins    4
# 1               0.568    36           2  17   Red Wings    8
# 2               0.444    25           0  17   Red Wings    6
# 3               0.565    21           0  16  Blackhawks   10
# 4               0.460    30           2  17   Red Wings    4
#
#   powerPlayConversion
# 0                 0/9
# 1                 0/3
# 2                 0/2
# 3                 0/3
# 4                 0/2
#        away_away_goals  away_blocks  away_faceoffWinningPctg  away_hits  \
# count        90.000000    90.000000                90.000000  90.000000
# mean          3.055556    14.511111                 0.484844  20.777778
# std           1.886446     5.313211                 0.076285   7.734031
# min           0.000000     6.000000                 0.317000   6.000000
# 25%           1.250000    11.000000                 0.432500  15.000000
# 50%           3.000000    13.000000                 0.485000  20.000000
# 75%           5.000000    17.000000                 0.530500  26.500000
# max           8.000000    31.000000                 0.674000  39.000000
#
#          away_id   away_pim     blocks  faceoffWinningPctg       hits  \
# count  90.000000  90.000000  90.000000           90.000000  90.000000
# mean   16.855556   8.844444  13.666667            0.515156  22.033333
# std     9.858050   5.394361   5.344324            0.076285   7.079723
# min     1.000000   0.000000   4.000000            0.326000   8.000000
# 25%    13.250000   6.000000  10.000000            0.469500  17.000000
# 50%    17.000000   8.000000  13.000000            0.515000  22.000000
# 75%    17.000000  10.000000  17.000000            0.567500  27.000000
# max    55.000000  35.000000  28.000000            0.683000  38.000000
#
#        home_goals         id        pim
# count   90.000000  90.000000  90.000000
# mean     3.177778  17.100000   7.688889
# std      1.764683   9.873412   4.015824
# min      0.000000   1.000000   2.000000
# 25%      2.000000  14.250000   6.000000
# 50%      3.000000  17.000000   6.000000
# 75%      4.000000  17.000000  10.000000
# max      8.000000  55.000000  27.000000
